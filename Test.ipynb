# %% [markdown]
# # Test

# %% [markdown]
# This is a test to see how the IPython Notebook displays on github

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_digits
digits = load_digits()

# %%
plt.matshow(digits.images[0], cmap=plt.cm.Greys);

# %%
X = digits.data.reshape(-1, 64)
print(X.shape)
# Out:
# (1797, 64)

# %%
y = digits.target
print(y.shape)
# Out:
# (1797,)

# %%
print(X)
# Out:
# [[  0.   0.   5. ...,   0.   0.   0.]
#  [  0.   0.   0. ...,  10.   0.   0.]
#  [  0.   0.   0. ...,  16.   9.   0.]
#  ...,
#  [  0.   0.   1. ...,   6.   0.   0.]
#  [  0.   0.   2. ...,  12.   0.   0.]
#  [  0.   0.  10. ...,  12.   1.   0.]]

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
pca.fit(X);

# %%
X_pca = pca.transform(X)
X_pca.shape
# Out:
# (1797, 2)

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y);
